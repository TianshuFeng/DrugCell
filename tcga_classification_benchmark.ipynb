# %% [markdown]
# ### Import the Data

# %%
# %run  Data_preparation_TCGA.ipynb
# Out:
# Mon Oct 13 18:43:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.05              Driver Version: 560.35.05      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:81:00.0 Off |                   On |
# | N/A   26C    P0             57W /  500W |    1421MiB /  81920MiB |     N/A      Default |
# |                                         |                        |            Disabled* |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | MIG devices:                                                                            |
# +------------------+----------------------------------+-----------+-----------------------+
# | GPU  GI  CI  MIG |                     Memory-Usage |        Vol|        Shared         |
# |      ID  ID  Dev |                       BAR1-Usage | SM     Unc| CE ENC  DEC  OFA  JPG |
# |                  |                                  |        ECC|                       |
# |==================+==================================+===========+=======================|
# |  0    1   0   0  |              41MiB / 40192MiB    | 42      0 |  3   0    2    0    0 |
# |                  |                 0MiB / 65535MiB  |           |                       |
# +------------------+----------------------------------+-----------+-----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Total number of cell lines = 1225
# Total number of drugs = 684
# There are 3008 genes
# There are 1 roots: GO:0008150
# There are 2086 terms
# There are 1 connected componenets
# 100%|██████████| 2702/2702 [00:08<00:00, 320.50it/s]

# %% [markdown]
# ### Import the Model

# %%
from Classification_model import *

# %% [markdown]
# ### Training Process

# %%
train_epochs = 200

train_loader = DataLoader(training_set, batch_size=1024, shuffle=True)
test_loader = DataLoader(testing_set, batch_size=5096, shuffle=False)

# %%
torch.manual_seed(0)

num_hiddens_genotype = 16
num_hiddens_final = 16

model = Drugcell_Vae(term_size_map, term_direct_gene_map, dG, num_genes, 
                 root, num_hiddens_genotype, num_hiddens_final, n_class = len(cancer_2_idx))

# %%
def create_term_mask(term_direct_gene_map, gene_dim, device):

    term_mask_map = {}

    for term, gene_set in term_direct_gene_map.items():

        mask = torch.zeros(len(gene_set), gene_dim)

        for i, gene_id in enumerate(gene_set):
            mask[i, gene_id] = 1

        mask_gpu = torch.autograd.Variable(mask)

        term_mask_map[term] = mask_gpu.to(device)

    return term_mask_map

term_mask_map = create_term_mask(model.term_direct_gene_map, num_genes, device = DEVICE)

# %%
for name, param in model.named_parameters():
    print(f"{name}: requires_grad={param.requires_grad}")
# Out:
# GO:0007005_direct_gene_layer.weight: requires_grad=True
# GO:0007005_direct_gene_layer.bias: requires_grad=True
# GO:0006281_direct_gene_layer.weight: requires_grad=True
# GO:0006281_direct_gene_layer.bias: requires_grad=True
# GO:0051052_direct_gene_layer.weight: requires_grad=True
# GO:0051052_direct_gene_layer.bias: requires_grad=True
# GO:0000070_direct_gene_layer.weight: requires_grad=True
# GO:0000070_direct_gene_layer.bias: requires_grad=True
# GO:1903047_direct_gene_layer.weight: requires_grad=True
# GO:1903047_direct_gene_layer.bias: requires_grad=True
# GO:0022618_direct_gene_layer.weight: requires_grad=True
# GO:0022618_direct_gene_layer.bias: requires_grad=True
# GO:0006631_direct_gene_layer.weight: requires_grad=True
# GO:0006631_direct_gene_layer.bias: requires_grad=True
# GO:0000038_direct_gene_layer.weight: requires_grad=True
# GO:0000038_direct_gene_layer.bias: requires_grad=True
# GO:0030001_direct_gene_layer.weight: requires_grad=True
# GO:0030001_direct_gene_layer.bias: requires_grad=True
# GO:0070925_direct_gene_layer.weight: requires_grad=True
# GO:0070925_direct_gene_layer.bias: requires_grad=True
# GO:1901566_direct_gene_layer.weight: requires_grad=True
# GO:1901566_direct_gene_layer.bias: requires_grad=True
# GO:0043604_direct_gene_layer.weight: requires_grad=True
# GO:0043604_direct_gene_layer.bias: requires_grad=True
# GO:1901605_direct_gene_layer.weight: requires_grad=True
# GO:1901605_direct_gene_layer.bias: requires_grad=True
# GO:0006575_direct_gene_layer.weight: requires_grad=True
# GO:0006575_direct_gene_layer.bias: requires_grad=True
# GO:0051656_direct_gene_layer.weight: requires_grad=True
# GO:0051656_direct_gene_layer.bias: requires_grad=True
# GO:0042254_direct_gene_layer.weight: requires_grad=True
# GO:0042254_direct_gene_layer.bias: requires_grad=True
# GO:0045786_direct_gene_layer.weight: requires_grad=True
# GO:0045786_direct_gene_layer.bias: requires_grad=True
# GO:0006974_direct_gene_layer.weight: requires_grad=True
# GO:0006974_direct_gene_layer.bias: requires_grad=True
# GO:0071900_direct_gene_layer.weight: requires_grad=True
# GO:0071900_direct_gene_layer.bias: requires_grad=True
# GO:1904029_direct_gene_layer.weight: requires_grad=True
# GO:1904029_direct_gene_layer.bias: requires_grad=True
# GO:0000082_direct_gene_layer.weight: requires_grad=True
# GO:0000082_direct_gene_layer.bias: requires_grad=True
# GO:0044772_direct_gene_layer.weight: requires_grad=True
# GO:0044772_direct_gene_layer.bias: requires_grad=True
# GO:0006355_direct_gene_layer.weight: requires_grad=True
# GO:0006355_direct_gene_layer.bias: requires_grad=True
# GO:0000083_direct_gene_layer.weight: requires_grad=True
# GO:0000083_direct_gene_layer.bias: requires_grad=True
# GO:0000086_direct_gene_layer.weight: requires_grad=True
# GO:0000086_direct_gene_layer.bias: requires_grad=True
# GO:0000096_direct_gene_layer.weight: requires_grad=True
# GO:0000096_direct_gene_layer.bias: requires_grad=True
# GO:0006790_direct_gene_layer.weight: requires_grad=True
# GO:0006790_direct_gene_layer.bias: requires_grad=True
# GO:0044272_direct_gene_layer.weight: requires_grad=True
# GO:0044272_direct_gene_layer.bias: requires_grad=True
# GO:0044273_direct_gene_layer.weight: requires_grad=True
# GO:0044273_direct_gene_layer.bias: requires_grad=True
# GO:0009063_direct_gene_layer.weight: requires_grad=True
# GO:0009063_direct_gene_layer.bias: requires_grad=True
# GO:1901607_direct_gene_layer.weight: requires_grad=True
# GO:1901607_direct_gene_layer.bias: requires_grad=True
# GO:0045892_direct_gene_layer.weight: requires_grad=True
# GO:0045892_direct_gene_layer.bias: requires_grad=True
# GO:0000122_direct_gene_layer.weight: requires_grad=True
# GO:0000122_direct_gene_layer.bias: requires_grad=True
# GO:0006357_direct_gene_layer.weight: requires_grad=True
# GO:0006357_direct_gene_layer.bias: requires_grad=True
# GO:0022607_direct_gene_layer.weight: requires_grad=True
# GO:0022607_direct_gene_layer.bias: requires_grad=True
# GO:0009451_direct_gene_layer.weight: requires_grad=True
# GO:0009451_direct_gene_layer.bias: requires_grad=True
# GO:0035556_direct_gene_layer.weight: requires_grad=True
# GO:0035556_direct_gene_layer.bias: requires_grad=True
# GO:0051403_direct_gene_layer.weight: requires_grad=True
# GO:0051403_direct_gene_layer.bias: requires_grad=True
# GO:0000165_direct_gene_layer.weight: requires_grad=True
# GO:0000165_direct_gene_layer.bias: requires_grad=True
# GO:0000186_direct_gene_layer.weight: requires_grad=True
# GO:0000186_direct_gene_layer.bias: requires_grad=True
# GO:0000187_direct_gene_layer.weight: requires_grad=True
# GO:0000187_direct_gene_layer.bias: requires_grad=True
# GO:0006342_direct_gene_layer.weight: requires_grad=True
# GO:0006342_direct_gene_layer.bias: requires_grad=True
# GO:0000956_direct_gene_layer.weight: requires_grad=True
# GO:0000956_direct_gene_layer.bias: requires_grad=True
# GO:0043406_direct_gene_layer.weight: requires_grad=True
# GO:0043406_direct_gene_layer.bias: requires_grad=True
# GO:0032147_direct_gene_layer.weight: requires_grad=True
# GO:0032147_direct_gene_layer.bias: requires_grad=True
# GO:0043407_direct_gene_layer.weight: requires_grad=True
# GO:0043407_direct_gene_layer.bias: requires_grad=True
# GO:0016567_direct_gene_layer.weight: requires_grad=True
# GO:0016567_direct_gene_layer.bias: requires_grad=True
# GO:0000209_direct_gene_layer.weight: requires_grad=True
# GO:0000209_direct_gene_layer.bias: requires_grad=True
# GO:0007051_direct_gene_layer.weight: requires_grad=True
# GO:0007051_direct_gene_layer.bias: requires_grad=True
# GO:0007010_direct_gene_layer.weight: requires_grad=True
# GO:0007010_direct_gene_layer.bias: requires_grad=True
# GO:0000226_direct_gene_layer.weight: requires_grad=True
# GO:0000226_direct_gene_layer.bias: requires_grad=True
# GO:0000398_direct_gene_layer.weight: requires_grad=True
# GO:0000398_direct_gene_layer.bias: requires_grad=True
# GO:0017144_direct_gene_layer.weight: requires_grad=True
# GO:0017144_direct_gene_layer.bias: requires_grad=True
# GO:0043603_direct_gene_layer.weight: requires_grad=True
# GO:0043603_direct_gene_layer.bias: requires_grad=True
# GO:0042737_direct_gene_layer.weight: requires_grad=True
# GO:0042737_direct_gene_layer.bias: requires_grad=True
# GO:1901565_direct_gene_layer.weight: requires_grad=True
# GO:1901565_direct_gene_layer.bias: requires_grad=True
# GO:1901361_direct_gene_layer.weight: requires_grad=True
# GO:1901361_direct_gene_layer.bias: requires_grad=True
# GO:0016051_direct_gene_layer.weight: requires_grad=True
# GO:0016051_direct_gene_layer.bias: requires_grad=True
# GO:0009057_direct_gene_layer.weight: requires_grad=True
# GO:0009057_direct_gene_layer.bias: requires_grad=True
# GO:0016052_direct_gene_layer.weight: requires_grad=True
# GO:0016052_direct_gene_layer.bias: requires_grad=True
# GO:0000281_direct_gene_layer.weight: requires_grad=True
# GO:0000281_direct_gene_layer.bias: requires_grad=True
# GO:0030010_direct_gene_layer.weight: requires_grad=True
# GO:0030010_direct_gene_layer.bias: requires_grad=True
# GO:0006401_direct_gene_layer.weight: requires_grad=True
# GO:0006401_direct_gene_layer.bias: requires_grad=True
# GO:0015696_direct_gene_layer.weight: requires_grad=True
# GO:0015696_direct_gene_layer.bias: requires_grad=True
# GO:0006979_direct_gene_layer.weight: requires_grad=True
# GO:0006979_direct_gene_layer.bias: requires_grad=True
# GO:0000302_direct_gene_layer.weight: requires_grad=True
# GO:0000302_direct_gene_layer.bias: requires_grad=True
# GO:0007584_direct_gene_layer.weight: requires_grad=True
# GO:0007584_direct_gene_layer.bias: requires_grad=True
# GO:0042493_direct_gene_layer.weight: requires_grad=True
# GO:0042493_direct_gene_layer.bias: requires_grad=True
# GO:0010035_direct_gene_layer.weight: requires_grad=True
# GO:0010035_direct_gene_layer.bias: requires_grad=True
# GO:0022402_direct_gene_layer.weight: requires_grad=True
# GO:0022402_direct_gene_layer.bias: requires_grad=True
# GO:0016070_direct_gene_layer.weight: requires_grad=True
# GO:0016070_direct_gene_layer.bias: requires_grad=True
# GO:0006396_direct_gene_layer.weight: requires_grad=True
# GO:0006396_direct_gene_layer.bias: requires_grad=True
# GO:0016570_direct_gene_layer.weight: requires_grad=True
# GO:0016570_direct_gene_layer.bias: requires_grad=True
# GO:0000413_direct_gene_layer.weight: requires_grad=True
# GO:0000413_direct_gene_layer.bias: requires_grad=True
# GO:0031062_direct_gene_layer.weight: requires_grad=True
# GO:0031062_direct_gene_layer.bias: requires_grad=True
# GO:0045944_direct_gene_layer.weight: requires_grad=True
# GO:0045944_direct_gene_layer.bias: requires_grad=True
# GO:0090501_direct_gene_layer.weight: requires_grad=True
# GO:0090501_direct_gene_layer.bias: requires_grad=True
# GO:0009880_direct_gene_layer.weight: requires_grad=True
# GO:0009880_direct_gene_layer.bias: requires_grad=True
# GO:0007127_direct_gene_layer.weight: requires_grad=True
# GO:0007127_direct_gene_layer.bias: requires_grad=True
# GO:0051276_direct_gene_layer.weight: requires_grad=True
# GO:0051276_direct_gene_layer.bias: requires_grad=True
# GO:0006283_direct_gene_layer.weight: requires_grad=True
# GO:0006283_direct_gene_layer.bias: requires_grad=True
# GO:0032508_direct_gene_layer.weight: requires_grad=True
# GO:0032508_direct_gene_layer.bias: requires_grad=True
# GO:0000723_direct_gene_layer.weight: requires_grad=True
# GO:0000723_direct_gene_layer.bias: requires_grad=True
# GO:0006259_direct_gene_layer.weight: requires_grad=True
# GO:0006259_direct_gene_layer.bias: requires_grad=True
# GO:0060249_direct_gene_layer.weight: requires_grad=True
# GO:0060249_direct_gene_layer.bias: requires_grad=True
# GO:0000724_direct_gene_layer.weight: requires_grad=True
# GO:0000724_direct_gene_layer.bias: requires_grad=True
# GO:0071897_direct_gene_layer.weight: requires_grad=True
# GO:0071897_direct_gene_layer.bias: requires_grad=True
# GO:0019953_direct_gene_layer.weight: requires_grad=True
# GO:0019953_direct_gene_layer.bias: requires_grad=True
# GO:0044703_direct_gene_layer.weight: requires_grad=True
# GO:0044703_direct_gene_layer.bias: requires_grad=True
# GO:0003006_direct_gene_layer.weight: requires_grad=True
# GO:0003006_direct_gene_layer.bias: requires_grad=True
# GO:0023058_direct_gene_layer.weight: requires_grad=True
# GO:0023058_direct_gene_layer.bias: requires_grad=True
# GO:0009914_direct_gene_layer.weight: requires_grad=True
# GO:0009914_direct_gene_layer.bias: requires_grad=True
# GO:0098813_direct_gene_layer.weight: requires_grad=True
# GO:0098813_direct_gene_layer.bias: requires_grad=True
# GO:0006521_direct_gene_layer.weight: requires_grad=True
# GO:0006521_direct_gene_layer.bias: requires_grad=True
# GO:0048468_direct_gene_layer.weight: requires_grad=True
# GO:0048468_direct_gene_layer.bias: requires_grad=True
# GO:0000904_direct_gene_layer.weight: requires_grad=True
# GO:0000904_direct_gene_layer.bias: requires_grad=True
# GO:0051301_direct_gene_layer.weight: requires_grad=True
# GO:0051301_direct_gene_layer.bias: requires_grad=True
# GO:0034622_direct_gene_layer.weight: requires_grad=True
# GO:0034622_direct_gene_layer.bias: requires_grad=True
# GO:0046165_direct_gene_layer.weight: requires_grad=True
# GO:0046165_direct_gene_layer.bias: requires_grad=True
# GO:0046394_direct_gene_layer.weight: requires_grad=True
# GO:0046394_direct_gene_layer.bias: requires_grad=True
# GO:0009074_direct_gene_layer.weight: requires_grad=True
# GO:0009074_direct_gene_layer.bias: requires_grad=True
# GO:0051252_direct_gene_layer.weight: requires_grad=True
# GO:0051252_direct_gene_layer.bias: requires_grad=True
# GO:0031329_direct_gene_layer.weight: requires_grad=True
# GO:0031329_direct_gene_layer.bias: requires_grad=True
# GO:0031331_direct_gene_layer.weight: requires_grad=True
# GO:0031331_direct_gene_layer.bias: requires_grad=True
# GO:0006366_direct_gene_layer.weight: requires_grad=True
# GO:0006366_direct_gene_layer.bias: requires_grad=True
# GO:0045839_direct_gene_layer.weight: requires_grad=True
# GO:0045839_direct_gene_layer.bias: requires_grad=True
# GO:0001101_direct_gene_layer.weight: requires_grad=True
# GO:0001101_direct_gene_layer.bias: requires_grad=True
# GO:0006367_direct_gene_layer.weight: requires_grad=True
# GO:0006367_direct_gene_layer.bias: requires_grad=True
# GO:0043933_direct_gene_layer.weight: requires_grad=True
# GO:0043933_direct_gene_layer.bias: requires_grad=True
# GO:0071824_direct_gene_layer.weight: requires_grad=True
# GO:0071824_direct_gene_layer.bias: requires_grad=True
# GO:0051128_direct_gene_layer.weight: requires_grad=True
# GO:0051128_direct_gene_layer.bias: requires_grad=True
# GO:0006325_direct_gene_layer.weight: requires_grad=True
# GO:0006325_direct_gene_layer.bias: requires_grad=True
# GO:0006464_direct_gene_layer.weight: requires_grad=True
# GO:0006464_direct_gene_layer.bias: requires_grad=True
# GO:0008104_direct_gene_layer.weight: requires_grad=True
# GO:0008104_direct_gene_layer.bias: requires_grad=True
# GO:0034599_direct_gene_layer.weight: requires_grad=True
# GO:0034599_direct_gene_layer.bias: requires_grad=True
# GO:0007165_direct_gene_layer.weight: requires_grad=True
# GO:0007165_direct_gene_layer.bias: requires_grad=True
# GO:0015711_direct_gene_layer.weight: requires_grad=True
# GO:0015711_direct_gene_layer.bias: requires_grad=True
# GO:0098656_direct_gene_layer.weight: requires_grad=True
# GO:0098656_direct_gene_layer.bias: requires_grad=True
# GO:0001501_direct_gene_layer.weight: requires_grad=True
# GO:0001501_direct_gene_layer.bias: requires_grad=True
# GO:0048705_direct_gene_layer.weight: requires_grad=True
# GO:0048705_direct_gene_layer.bias: requires_grad=True
# GO:0001503_direct_gene_layer.weight: requires_grad=True
# GO:0001503_direct_gene_layer.bias: requires_grad=True
# GO:0098657_direct_gene_layer.weight: requires_grad=True
# GO:0098657_direct_gene_layer.bias: requires_grad=True
# GO:0001504_direct_gene_layer.weight: requires_grad=True
# GO:0001504_direct_gene_layer.bias: requires_grad=True
# GO:0006836_direct_gene_layer.weight: requires_grad=True
# GO:0006836_direct_gene_layer.bias: requires_grad=True
# GO:0001505_direct_gene_layer.weight: requires_grad=True
# GO:0001505_direct_gene_layer.bias: requires_grad=True
# GO:0007271_direct_gene_layer.weight: requires_grad=True
# GO:0007271_direct_gene_layer.bias: requires_grad=True
# GO:0042391_direct_gene_layer.weight: requires_grad=True
# GO:0042391_direct_gene_layer.bias: requires_grad=True
# GO:0046457_direct_gene_layer.weight: requires_grad=True
# GO:0046457_direct_gene_layer.bias: requires_grad=True
# GO:0048646_direct_gene_layer.weight: requires_grad=True
# GO:0048646_direct_gene_layer.bias: requires_grad=True
# GO:0001525_direct_gene_layer.weight: requires_grad=True
# GO:0001525_direct_gene_layer.bias: requires_grad=True
# GO:0001541_direct_gene_layer.weight: requires_grad=True
# GO:0001541_direct_gene_layer.bias: requires_grad=True
# GO:0048608_direct_gene_layer.weight: requires_grad=True
# GO:0048608_direct_gene_layer.bias: requires_grad=True
# GO:0022602_direct_gene_layer.weight: requires_grad=True
# GO:0022602_direct_gene_layer.bias: requires_grad=True
# GO:0030728_direct_gene_layer.weight: requires_grad=True
# GO:0030728_direct_gene_layer.bias: requires_grad=True
# GO:0048589_direct_gene_layer.weight: requires_grad=True
# GO:0048589_direct_gene_layer.bias: requires_grad=True
# GO:0022412_direct_gene_layer.weight: requires_grad=True
# GO:0022412_direct_gene_layer.bias: requires_grad=True
# GO:0030855_direct_gene_layer.weight: requires_grad=True
# GO:0030855_direct_gene_layer.bias: requires_grad=True
# GO:0048599_direct_gene_layer.weight: requires_grad=True
# GO:0048599_direct_gene_layer.bias: requires_grad=True
# GO:0071695_direct_gene_layer.weight: requires_grad=True
# GO:0071695_direct_gene_layer.bias: requires_grad=True
# GO:0048469_direct_gene_layer.weight: requires_grad=True
# GO:0048469_direct_gene_layer.bias: requires_grad=True
# GO:0001558_direct_gene_layer.weight: requires_grad=True
# GO:0001558_direct_gene_layer.bias: requires_grad=True
# GO:0040008_direct_gene_layer.weight: requires_grad=True
# GO:0040008_direct_gene_layer.bias: requires_grad=True
# GO:0061387_direct_gene_layer.weight: requires_grad=True
# GO:0061387_direct_gene_layer.bias: requires_grad=True
# GO:0051707_direct_gene_layer.weight: requires_grad=True
# GO:0051707_direct_gene_layer.bias: requires_grad=True
# GO:0001944_direct_gene_layer.weight: requires_grad=True
# GO:0001944_direct_gene_layer.bias: requires_grad=True
# GO:0001569_direct_gene_layer.weight: requires_grad=True
# GO:0001569_direct_gene_layer.bias: requires_grad=True
# GO:0048754_direct_gene_layer.weight: requires_grad=True
# GO:0048754_direct_gene_layer.bias: requires_grad=True
# GO:0001570_direct_gene_layer.weight: requires_grad=True
# GO:0001570_direct_gene_layer.bias: requires_grad=True
# GO:0046513_direct_gene_layer.weight: requires_grad=True
# GO:0046513_direct_gene_layer.bias: requires_grad=True
# GO:0006687_direct_gene_layer.weight: requires_grad=True
# GO:0006687_direct_gene_layer.bias: requires_grad=True
# GO:0015908_direct_gene_layer.weight: requires_grad=True
# GO:0015908_direct_gene_layer.bias: requires_grad=True
# GO:0050912_direct_gene_layer.weight: requires_grad=True
# GO:0050912_direct_gene_layer.bias: requires_grad=True
# GO:0050913_direct_gene_layer.weight: requires_grad=True
# GO:0050913_direct_gene_layer.bias: requires_grad=True
# GO:0001649_direct_gene_layer.weight: requires_grad=True
# GO:0001649_direct_gene_layer.bias: requires_grad=True
# GO:0007423_direct_gene_layer.weight: requires_grad=True
# GO:0007423_direct_gene_layer.bias: requires_grad=True
# GO:0150063_direct_gene_layer.weight: requires_grad=True
# GO:0150063_direct_gene_layer.bias: requires_grad=True
# GO:0001822_direct_gene_layer.weight: requires_grad=True
# GO:0001822_direct_gene_layer.bias: requires_grad=True
# GO:0001656_direct_gene_layer.weight: requires_grad=True
# GO:0001656_direct_gene_layer.bias: requires_grad=True
# GO:0001657_direct_gene_layer.weight: requires_grad=True
# GO:0001657_direct_gene_layer.bias: requires_grad=True
# GO:0001658_direct_gene_layer.weight: requires_grad=True
# GO:0001658_direct_gene_layer.bias: requires_grad=True
# GO:0048871_direct_gene_layer.weight: requires_grad=True
# GO:0048871_direct_gene_layer.bias: requires_grad=True
# GO:0001659_direct_gene_layer.weight: requires_grad=True
# GO:0001659_direct_gene_layer.bias: requires_grad=True
# GO:0006953_direct_gene_layer.weight: requires_grad=True
# GO:0006953_direct_gene_layer.bias: requires_grad=True
# GO:0001662_direct_gene_layer.weight: requires_grad=True
# GO:0001662_direct_gene_layer.bias: requires_grad=True
# GO:0001666_direct_gene_layer.weight: requires_grad=True
# GO:0001666_direct_gene_layer.bias: requires_grad=True
# GO:0016477_direct_gene_layer.weight: requires_grad=True
# GO:0016477_direct_gene_layer.bias: requires_grad=True
# GO:0007286_direct_gene_layer.weight: requires_grad=True
# GO:0007286_direct_gene_layer.bias: requires_grad=True
# GO:0010927_direct_gene_layer.weight: requires_grad=True
# GO:0010927_direct_gene_layer.bias: requires_grad=True
# GO:0001676_direct_gene_layer.weight: requires_grad=True
# GO:0001676_direct_gene_layer.bias: requires_grad=True
# GO:0006413_direct_gene_layer.weight: requires_grad=True
# GO:0006413_direct_gene_layer.bias: requires_grad=True
# GO:0055082_direct_gene_layer.weight: requires_grad=True
# GO:0055082_direct_gene_layer.bias: requires_grad=True
# GO:0042593_direct_gene_layer.weight: requires_grad=True
# GO:0042593_direct_gene_layer.bias: requires_grad=True
# GO:0097164_direct_gene_layer.weight: requires_grad=True
# GO:0097164_direct_gene_layer.bias: requires_grad=True
# GO:1901362_direct_gene_layer.weight: requires_grad=True
# GO:1901362_direct_gene_layer.bias: requires_grad=True
# GO:0042136_direct_gene_layer.weight: requires_grad=True
# GO:0042136_direct_gene_layer.bias: requires_grad=True
# GO:0019438_direct_gene_layer.weight: requires_grad=True
# GO:0019438_direct_gene_layer.bias: requires_grad=True
# GO:0042402_direct_gene_layer.weight: requires_grad=True
# GO:0042402_direct_gene_layer.bias: requires_grad=True
# GO:0042135_direct_gene_layer.weight: requires_grad=True
# GO:0042135_direct_gene_layer.bias: requires_grad=True
# GO:0043009_direct_gene_layer.weight: requires_grad=True
# GO:0043009_direct_gene_layer.bias: requires_grad=True
# GO:0001701_direct_gene_layer.weight: requires_grad=True
# GO:0001701_direct_gene_layer.bias: requires_grad=True
# GO:0007369_direct_gene_layer.weight: requires_grad=True
# GO:0007369_direct_gene_layer.bias: requires_grad=True
# GO:0001704_direct_gene_layer.weight: requires_grad=True
# GO:0001704_direct_gene_layer.bias: requires_grad=True
# GO:0045165_direct_gene_layer.weight: requires_grad=True
# GO:0045165_direct_gene_layer.bias: requires_grad=True
# GO:0001708_direct_gene_layer.weight: requires_grad=True
# GO:0001708_direct_gene_layer.bias: requires_grad=True
# GO:0048333_direct_gene_layer.weight: requires_grad=True
# GO:0048333_direct_gene_layer.bias: requires_grad=True
# GO:0035987_direct_gene_layer.weight: requires_grad=True
# GO:0035987_direct_gene_layer.bias: requires_grad=True
# GO:0048598_direct_gene_layer.weight: requires_grad=True
# GO:0048598_direct_gene_layer.bias: requires_grad=True
# GO:0001754_direct_gene_layer.weight: requires_grad=True
# GO:0001754_direct_gene_layer.bias: requires_grad=True
# GO:0001755_direct_gene_layer.weight: requires_grad=True
# GO:0001755_direct_gene_layer.bias: requires_grad=True
# GO:0001756_direct_gene_layer.weight: requires_grad=True
# GO:0001756_direct_gene_layer.bias: requires_grad=True
# GO:0003156_direct_gene_layer.weight: requires_grad=True
# GO:0003156_direct_gene_layer.bias: requires_grad=True
# GO:0031128_direct_gene_layer.weight: requires_grad=True
# GO:0031128_direct_gene_layer.bias: requires_grad=True
# GO:0110110_direct_gene_layer.weight: requires_grad=True
# GO:0110110_direct_gene_layer.bias: requires_grad=True
# GO:0009653_direct_gene_layer.weight: requires_grad=True
# GO:0009653_direct_gene_layer.bias: requires_grad=True
# GO:0001764_direct_gene_layer.weight: requires_grad=True
# GO:0001764_direct_gene_layer.bias: requires_grad=True
# GO:0046649_direct_gene_layer.weight: requires_grad=True
# GO:0046649_direct_gene_layer.bias: requires_grad=True
# GO:0042110_direct_gene_layer.weight: requires_grad=True
# GO:0042110_direct_gene_layer.bias: requires_grad=True
# GO:0030101_direct_gene_layer.weight: requires_grad=True
# GO:0030101_direct_gene_layer.bias: requires_grad=True
# GO:0009988_direct_gene_layer.weight: requires_grad=True
# GO:0009988_direct_gene_layer.bias: requires_grad=True
# GO:0002274_direct_gene_layer.weight: requires_grad=True
# GO:0002274_direct_gene_layer.bias: requires_grad=True
# GO:0001774_direct_gene_layer.weight: requires_grad=True
# GO:0001774_direct_gene_layer.bias: requires_grad=True
# GO:0048872_direct_gene_layer.weight: requires_grad=True
# GO:0048872_direct_gene_layer.bias: requires_grad=True
# GO:0043029_direct_gene_layer.weight: requires_grad=True
# GO:0043029_direct_gene_layer.bias: requires_grad=True
# GO:0042098_direct_gene_layer.weight: requires_grad=True
# GO:0042098_direct_gene_layer.bias: requires_grad=True
# GO:0007009_direct_gene_layer.weight: requires_grad=True
# GO:0007009_direct_gene_layer.bias: requires_grad=True
# GO:0042060_direct_gene_layer.weight: requires_grad=True
# GO:0042060_direct_gene_layer.bias: requires_grad=True
# GO:0030098_direct_gene_layer.weight: requires_grad=True
# GO:0030098_direct_gene_layer.bias: requires_grad=True
# GO:0071887_direct_gene_layer.weight: requires_grad=True
# GO:0071887_direct_gene_layer.bias: requires_grad=True
# GO:0001782_direct_gene_layer.weight: requires_grad=True
# GO:0001782_direct_gene_layer.bias: requires_grad=True
# GO:0001909_direct_gene_layer.weight: requires_grad=True
# GO:0001909_direct_gene_layer.bias: requires_grad=True
# GO:0016064_direct_gene_layer.weight: requires_grad=True
# GO:0016064_direct_gene_layer.bias: requires_grad=True
# GO:0002889_direct_gene_layer.weight: requires_grad=True
# GO:0002889_direct_gene_layer.bias: requires_grad=True
# GO:0002888_direct_gene_layer.weight: requires_grad=True
# GO:0002888_direct_gene_layer.bias: requires_grad=True
# GO:0002456_direct_gene_layer.weight: requires_grad=True
# GO:0002456_direct_gene_layer.bias: requires_grad=True
# GO:0001912_direct_gene_layer.weight: requires_grad=True
# GO:0001912_direct_gene_layer.bias: requires_grad=True
# GO:0001816_direct_gene_layer.weight: requires_grad=True
# GO:0001816_direct_gene_layer.bias: requires_grad=True
# GO:0001817_direct_gene_layer.weight: requires_grad=True
# GO:0001817_direct_gene_layer.bias: requires_grad=True
# GO:0001818_direct_gene_layer.weight: requires_grad=True
# GO:0001818_direct_gene_layer.bias: requires_grad=True
# GO:0051241_direct_gene_layer.weight: requires_grad=True
# GO:0051241_direct_gene_layer.bias: requires_grad=True
# GO:0001819_direct_gene_layer.weight: requires_grad=True
# GO:0001819_direct_gene_layer.bias: requires_grad=True
# GO:0051240_direct_gene_layer.weight: requires_grad=True
# GO:0051240_direct_gene_layer.bias: requires_grad=True
# GO:0032940_direct_gene_layer.weight: requires_grad=True
# GO:0032940_direct_gene_layer.bias: requires_grad=True
# GO:0046903_direct_gene_layer.weight: requires_grad=True
# GO:0046903_direct_gene_layer.bias: requires_grad=True
# GO:0048513_direct_gene_layer.weight: requires_grad=True
# GO:0048513_direct_gene_layer.bias: requires_grad=True
# GO:0001823_direct_gene_layer.weight: requires_grad=True
# GO:0001823_direct_gene_layer.bias: requires_grad=True
# GO:0001824_direct_gene_layer.weight: requires_grad=True
# GO:0001824_direct_gene_layer.bias: requires_grad=True
# GO:0008283_direct_gene_layer.weight: requires_grad=True
# GO:0008283_direct_gene_layer.bias: requires_grad=True
# GO:0008637_direct_gene_layer.weight: requires_grad=True
# GO:0008637_direct_gene_layer.bias: requires_grad=True
# GO:0097190_direct_gene_layer.weight: requires_grad=True
# GO:0097190_direct_gene_layer.bias: requires_grad=True
# GO:0016331_direct_gene_layer.weight: requires_grad=True
# GO:0016331_direct_gene_layer.bias: requires_grad=True
# GO:0060429_direct_gene_layer.weight: requires_grad=True
# GO:0060429_direct_gene_layer.bias: requires_grad=True
# GO:0001841_direct_gene_layer.weight: requires_grad=True
# GO:0001841_direct_gene_layer.bias: requires_grad=True
# GO:0001843_direct_gene_layer.weight: requires_grad=True
# GO:0001843_direct_gene_layer.bias: requires_grad=True
# GO:0016050_direct_gene_layer.weight: requires_grad=True
# GO:0016050_direct_gene_layer.bias: requires_grad=True
# GO:0007040_direct_gene_layer.weight: requires_grad=True
# GO:0007040_direct_gene_layer.bias: requires_grad=True
# GO:0006909_direct_gene_layer.weight: requires_grad=True
# GO:0006909_direct_gene_layer.bias: requires_grad=True
# GO:0045087_direct_gene_layer.weight: requires_grad=True
# GO:0045087_direct_gene_layer.bias: requires_grad=True
# GO:0030449_direct_gene_layer.weight: requires_grad=True
# GO:0030449_direct_gene_layer.bias: requires_grad=True
# GO:0045088_direct_gene_layer.weight: requires_grad=True
# GO:0045088_direct_gene_layer.bias: requires_grad=True
# GO:0045824_direct_gene_layer.weight: requires_grad=True
# GO:0045824_direct_gene_layer.bias: requires_grad=True
# GO:0009620_direct_gene_layer.weight: requires_grad=True
# GO:0009620_direct_gene_layer.bias: requires_grad=True
# GO:0046661_direct_gene_layer.weight: requires_grad=True
# GO:0046661_direct_gene_layer.bias: requires_grad=True
# GO:0002064_direct_gene_layer.weight: requires_grad=True
# GO:0002064_direct_gene_layer.bias: requires_grad=True
# GO:0045446_direct_gene_layer.weight: requires_grad=True
# GO:0045446_direct_gene_layer.bias: requires_grad=True
# GO:0048732_direct_gene_layer.weight: requires_grad=True
# GO:0048732_direct_gene_layer.bias: requires_grad=True
# GO:0001889_direct_gene_layer.weight: requires_grad=True
# GO:0001889_direct_gene_layer.bias: requires_grad=True
# GO:0001890_direct_gene_layer.weight: requires_grad=True
# GO:0001890_direct_gene_layer.bias: requires_grad=True
# GO:0048568_direct_gene_layer.weight: requires_grad=True
# GO:0048568_direct_gene_layer.bias: requires_grad=True
# GO:0060135_direct_gene_layer.weight: requires_grad=True
# GO:0060135_direct_gene_layer.bias: requires_grad=True
# GO:0001894_direct_gene_layer.weight: requires_grad=True
# GO:0001894_direct_gene_layer.bias: requires_grad=True
# GO:0001895_direct_gene_layer.weight: requires_grad=True
# GO:0001895_direct_gene_layer.bias: requires_grad=True
# GO:0010605_direct_gene_layer.weight: requires_grad=True
# GO:0010605_direct_gene_layer.bias: requires_grad=True
# GO:0023057_direct_gene_layer.weight: requires_grad=True
# GO:0023057_direct_gene_layer.bias: requires_grad=True
# GO:0045577_direct_gene_layer.weight: requires_grad=True
# GO:0045577_direct_gene_layer.bias: requires_grad=True
# GO:0140029_direct_gene_layer.weight: requires_grad=True
# GO:0140029_direct_gene_layer.bias: requires_grad=True
# GO:0043254_direct_gene_layer.weight: requires_grad=True
# GO:0043254_direct_gene_layer.bias: requires_grad=True
# GO:0017157_direct_gene_layer.weight: requires_grad=True
# GO:0017157_direct_gene_layer.bias: requires_grad=True
# GO:0031334_direct_gene_layer.weight: requires_grad=True
# GO:0031334_direct_gene_layer.bias: requires_grad=True
# GO:0045921_direct_gene_layer.weight: requires_grad=True
# GO:0045921_direct_gene_layer.bias: requires_grad=True
# GO:0001933_direct_gene_layer.weight: requires_grad=True
# GO:0001933_direct_gene_layer.bias: requires_grad=True
# GO:0031400_direct_gene_layer.weight: requires_grad=True
# GO:0031400_direct_gene_layer.bias: requires_grad=True
# GO:0001935_direct_gene_layer.weight: requires_grad=True
# GO:0001935_direct_gene_layer.bias: requires_grad=True
# GO:0050678_direct_gene_layer.weight: requires_grad=True
# GO:0050678_direct_gene_layer.bias: requires_grad=True
# GO:0001937_direct_gene_layer.weight: requires_grad=True
# GO:0001937_direct_gene_layer.bias: requires_grad=True
# GO:0001938_direct_gene_layer.weight: requires_grad=True
# GO:0001938_direct_gene_layer.bias: requires_grad=True
# GO:0050679_direct_gene_layer.weight: requires_grad=True
# GO:0050679_direct_gene_layer.bias: requires_grad=True
# GO:0061024_direct_gene_layer.weight: requires_grad=True
# GO:0061024_direct_gene_layer.bias: requires_grad=True
# GO:0001942_direct_gene_layer.weight: requires_grad=True
# GO:0001942_direct_gene_layer.bias: requires_grad=True
# GO:0001945_direct_gene_layer.weight: requires_grad=True
# GO:0001945_direct_gene_layer.bias: requires_grad=True
# GO:0001947_direct_gene_layer.weight: requires_grad=True
# GO:0001947_direct_gene_layer.bias: requires_grad=True
# GO:0009913_direct_gene_layer.weight: requires_grad=True
# GO:0009913_direct_gene_layer.bias: requires_grad=True
# GO:0010810_direct_gene_layer.weight: requires_grad=True
# GO:0010810_direct_gene_layer.bias: requires_grad=True
# GO:0001953_direct_gene_layer.weight: requires_grad=True
# GO:0001953_direct_gene_layer.bias: requires_grad=True
# GO:1903532_direct_gene_layer.weight: requires_grad=True
# GO:1903532_direct_gene_layer.bias: requires_grad=True
# GO:0051590_direct_gene_layer.weight: requires_grad=True
# GO:0051590_direct_gene_layer.bias: requires_grad=True
# GO:0050806_direct_gene_layer.weight: requires_grad=True
# GO:0050806_direct_gene_layer.bias: requires_grad=True
# GO:0001958_direct_gene_layer.weight: requires_grad=True
# GO:0001958_direct_gene_layer.bias: requires_grad=True
# GO:0001959_direct_gene_layer.weight: requires_grad=True
# GO:0001959_direct_gene_layer.bias: requires_grad=True
# GO:0001960_direct_gene_layer.weight: requires_grad=True
# GO:0001960_direct_gene_layer.bias: requires_grad=True
# GO:0009968_direct_gene_layer.weight: requires_grad=True
# GO:0009968_direct_gene_layer.bias: requires_grad=True
# GO:0001961_direct_gene_layer.weight: requires_grad=True
# GO:0001961_direct_gene_layer.bias: requires_grad=True
# GO:0007268_direct_gene_layer.weight: requires_grad=True
# GO:0007268_direct_gene_layer.bias: requires_grad=True
# GO:0048771_direct_gene_layer.weight: requires_grad=True
# GO:0048771_direct_gene_layer.bias: requires_grad=True
# GO:0001974_direct_gene_layer.weight: requires_grad=True
# GO:0001974_direct_gene_layer.bias: requires_grad=True
# GO:0001975_direct_gene_layer.weight: requires_grad=True
# GO:0001975_direct_gene_layer.bias: requires_grad=True
# GO:0009636_direct_gene_layer.weight: requires_grad=True
# GO:0009636_direct_gene_layer.bias: requires_grad=True
# GO:0009410_direct_gene_layer.weight: requires_grad=True
# GO:0009410_direct_gene_layer.bias: requires_grad=True
# GO:0050877_direct_gene_layer.weight: requires_grad=True
# GO:0050877_direct_gene_layer.bias: requires_grad=True
# GO:0003071_direct_gene_layer.weight: requires_grad=True
# GO:0003071_direct_gene_layer.bias: requires_grad=True
# GO:0050878_direct_gene_layer.weight: requires_grad=True
# GO:0050878_direct_gene_layer.bias: requires_grad=True
# GO:0042311_direct_gene_layer.weight: requires_grad=True
# GO:0042311_direct_gene_layer.bias: requires_grad=True
# GO:0045822_direct_gene_layer.weight: requires_grad=True
# GO:0045822_direct_gene_layer.bias: requires_grad=True
# GO:0042310_direct_gene_layer.weight: requires_grad=True
# GO:0042310_direct_gene_layer.bias: requires_grad=True
# GO:0010460_direct_gene_layer.weight: requires_grad=True
# GO:0010460_direct_gene_layer.bias: requires_grad=True
# GO:0003044_direct_gene_layer.weight: requires_grad=True
# GO:0003044_direct_gene_layer.bias: requires_grad=True
# GO:0010817_direct_gene_layer.weight: requires_grad=True
# GO:0010817_direct_gene_layer.bias: requires_grad=True
# GO:0002003_direct_gene_layer.weight: requires_grad=True
# GO:0002003_direct_gene_layer.bias: requires_grad=True
# GO:0048729_direct_gene_layer.weight: requires_grad=True
# GO:0048729_direct_gene_layer.bias: requires_grad=True
# GO:0002011_direct_gene_layer.weight: requires_grad=True
# GO:0002011_direct_gene_layer.bias: requires_grad=True
# GO:0003015_direct_gene_layer.weight: requires_grad=True
# GO:0003015_direct_gene_layer.bias: requires_grad=True
# GO:0031667_direct_gene_layer.weight: requires_grad=True
# GO:0031667_direct_gene_layer.bias: requires_grad=True
# GO:0002021_direct_gene_layer.weight: requires_grad=True
# GO:0002021_direct_gene_layer.bias: requires_grad=True
# GO:0042755_direct_gene_layer.weight: requires_grad=True
# GO:0042755_direct_gene_layer.bias: requires_grad=True
# GO:0008016_direct_gene_layer.weight: requires_grad=True
# GO:0008016_direct_gene_layer.bias: requires_grad=True
# GO:0002026_direct_gene_layer.weight: requires_grad=True
# GO:0002026_direct_gene_layer.bias: requires_grad=True
# GO:0010959_direct_gene_layer.weight: requires_grad=True
# GO:0010959_direct_gene_layer.bias: requires_grad=True
# GO:0002029_direct_gene_layer.weight: requires_grad=True
# GO:0002029_direct_gene_layer.bias: requires_grad=True
# GO:0006468_direct_gene_layer.weight: requires_grad=True
# GO:0006468_direct_gene_layer.bias: requires_grad=True
# GO:0031623_direct_gene_layer.weight: requires_grad=True
# GO:0031623_direct_gene_layer.bias: requires_grad=True
# GO:0032091_direct_gene_layer.weight: requires_grad=True
# GO:0032091_direct_gene_layer.bias: requires_grad=True
# GO:0097746_direct_gene_layer.weight: requires_grad=True
# GO:0097746_direct_gene_layer.bias: requires_grad=True
# GO:2001024_direct_gene_layer.weight: requires_grad=True
# GO:2001024_direct_gene_layer.bias: requires_grad=True
# GO:2001025_direct_gene_layer.weight: requires_grad=True
# GO:2001025_direct_gene_layer.bias: requires_grad=True
# GO:0051957_direct_gene_layer.weight: requires_grad=True
# GO:0051957_direct_gene_layer.bias: requires_grad=True
# GO:0002040_direct_gene_layer.weight: requires_grad=True
# GO:0002040_direct_gene_layer.bias: requires_grad=True
# GO:0043534_direct_gene_layer.weight: requires_grad=True
# GO:0043534_direct_gene_layer.bias: requires_grad=True
# GO:0030155_direct_gene_layer.weight: requires_grad=True
# GO:0030155_direct_gene_layer.bias: requires_grad=True
# GO:0044271_direct_gene_layer.weight: requires_grad=True
# GO:0044271_direct_gene_layer.bias: requires_grad=True
# GO:0050769_direct_gene_layer.weight: requires_grad=True
# GO:0050769_direct_gene_layer.bias: requires_grad=True
# GO:2000179_direct_gene_layer.weight: requires_grad=True
# GO:2000179_direct_gene_layer.bias: requires_grad=True
# GO:1902692_direct_gene_layer.weight: requires_grad=True
# GO:1902692_direct_gene_layer.bias: requires_grad=True
# GO:2000648_direct_gene_layer.weight: requires_grad=True
# GO:2000648_direct_gene_layer.bias: requires_grad=True
# GO:0008284_direct_gene_layer.weight: requires_grad=True
# GO:0008284_direct_gene_layer.bias: requires_grad=True
# GO:0002053_direct_gene_layer.weight: requires_grad=True
# GO:0002053_direct_gene_layer.bias: requires_grad=True
# GO:0002062_direct_gene_layer.weight: requires_grad=True
# GO:0002062_direct_gene_layer.bias: requires_grad=True
# GO:0002066_direct_gene_layer.weight: requires_grad=True
# GO:0002066_direct_gene_layer.bias: requires_grad=True
# GO:0002067_direct_gene_layer.weight: requires_grad=True
# GO:0002067_direct_gene_layer.bias: requires_grad=True
# GO:0043010_direct_gene_layer.weight: requires_grad=True
# GO:0043010_direct_gene_layer.bias: requires_grad=True
# GO:0007519_direct_gene_layer.weight: requires_grad=True
# GO:0007519_direct_gene_layer.bias: requires_grad=True
# GO:0061025_direct_gene_layer.weight: requires_grad=True
# GO:0061025_direct_gene_layer.bias: requires_grad=True
# GO:0043467_direct_gene_layer.weight: requires_grad=True
# GO:0043467_direct_gene_layer.bias: requires_grad=True
# GO:0035601_direct_gene_layer.weight: requires_grad=True
# GO:0035601_direct_gene_layer.bias: requires_grad=True
# GO:0022603_direct_gene_layer.weight: requires_grad=True
# GO:0022603_direct_gene_layer.bias: requires_grad=True
# GO:0030857_direct_gene_layer.weight: requires_grad=True
# GO:0030857_direct_gene_layer.bias: requires_grad=True
# GO:0002088_direct_gene_layer.weight: requires_grad=True
# GO:0002088_direct_gene_layer.bias: requires_grad=True
# GO:0048259_direct_gene_layer.weight: requires_grad=True
# GO:0048259_direct_gene_layer.bias: requires_grad=True
# GO:0002092_direct_gene_layer.weight: requires_grad=True
# GO:0002092_direct_gene_layer.bias: requires_grad=True
# GO:0048667_direct_gene_layer.weight: requires_grad=True
# GO:0048667_direct_gene_layer.bias: requires_grad=True
# GO:0042472_direct_gene_layer.weight: requires_grad=True
# GO:0042472_direct_gene_layer.bias: requires_grad=True
# GO:0006816_direct_gene_layer.weight: requires_grad=True
# GO:0006816_direct_gene_layer.bias: requires_grad=True
# GO:0042573_direct_gene_layer.weight: requires_grad=True
# GO:0042573_direct_gene_layer.bias: requires_grad=True
# GO:0072330_direct_gene_layer.weight: requires_grad=True
# GO:0072330_direct_gene_layer.bias: requires_grad=True
# GO:1903409_direct_gene_layer.weight: requires_grad=True
# GO:1903409_direct_gene_layer.bias: requires_grad=True
# GO:0044283_direct_gene_layer.weight: requires_grad=True
# GO:0044283_direct_gene_layer.bias: requires_grad=True
# GO:0044282_direct_gene_layer.weight: requires_grad=True
# GO:0044282_direct_gene_layer.bias: requires_grad=True
# GO:0008206_direct_gene_layer.weight: requires_grad=True
# GO:0008206_direct_gene_layer.bias: requires_grad=True
# GO:0030522_direct_gene_layer.weight: requires_grad=True
# GO:0030522_direct_gene_layer.bias: requires_grad=True
# GO:0007043_direct_gene_layer.weight: requires_grad=True
# GO:0007043_direct_gene_layer.bias: requires_grad=True
# GO:0009791_direct_gene_layer.weight: requires_grad=True
# GO:0009791_direct_gene_layer.bias: requires_grad=True
# GO:0030879_direct_gene_layer.weight: requires_grad=True
# GO:0030879_direct_gene_layer.bias: requires_grad=True
# GO:0034613_direct_gene_layer.weight: requires_grad=True
# GO:0034613_direct_gene_layer.bias: requires_grad=True
# GO:0016445_direct_gene_layer.weight: requires_grad=True
# GO:0016445_direct_gene_layer.bias: requires_grad=True
# GO:0006952_direct_gene_layer.weight: requires_grad=True
# GO:0006952_direct_gene_layer.bias: requires_grad=True
# GO:0007610_direct_gene_layer.weight: requires_grad=True
# GO:0007610_direct_gene_layer.bias: requires_grad=True
# GO:0009611_direct_gene_layer.weight: requires_grad=True
# GO:0009611_direct_gene_layer.bias: requires_grad=True
# GO:0098542_direct_gene_layer.weight: requires_grad=True
# GO:0098542_direct_gene_layer.bias: requires_grad=True
# GO:0002758_direct_gene_layer.weight: requires_grad=True
# GO:0002758_direct_gene_layer.bias: requires_grad=True
# GO:0002429_direct_gene_layer.weight: requires_grad=True
# GO:0002429_direct_gene_layer.bias: requires_grad=True
# GO:0002223_direct_gene_layer.weight: requires_grad=True
# GO:0002223_direct_gene_layer.bias: requires_grad=True
# GO:0002224_direct_gene_layer.weight: requires_grad=True
# GO:0002224_direct_gene_layer.bias: requires_grad=True
# GO:0002702_direct_gene_layer.weight: requires_grad=True
# GO:0002702_direct_gene_layer.bias: requires_grad=True
# GO:0030595_direct_gene_layer.weight: requires_grad=True
# GO:0030595_direct_gene_layer.bias: requires_grad=True
# GO:0006986_direct_gene_layer.weight: requires_grad=True
# GO:0006986_direct_gene_layer.bias: requires_grad=True
# GO:0009617_direct_gene_layer.weight: requires_grad=True
# GO:0009617_direct_gene_layer.bias: requires_grad=True
# GO:0002244_direct_gene_layer.weight: requires_grad=True
# GO:0002244_direct_gene_layer.bias: requires_grad=True
# GO:0030097_direct_gene_layer.weight: requires_grad=True
# GO:0030097_direct_gene_layer.bias: requires_grad=True
# GO:0006955_direct_gene_layer.weight: requires_grad=True
# GO:0006955_direct_gene_layer.bias: requires_grad=True
# GO:0002250_direct_gene_layer.weight: requires_grad=True
# GO:0002250_direct_gene_layer.bias: requires_grad=True
# GO:0002252_direct_gene_layer.weight: requires_grad=True
# GO:0002252_direct_gene_layer.bias: requires_grad=True
# GO:0050778_direct_gene_layer.weight: requires_grad=True
# GO:0050778_direct_gene_layer.bias: requires_grad=True
# GO:0002675_direct_gene_layer.weight: requires_grad=True
# GO:0002675_direct_gene_layer.bias: requires_grad=True
# GO:0048143_direct_gene_layer.weight: requires_grad=True
# GO:0048143_direct_gene_layer.bias: requires_grad=True
# GO:0006954_direct_gene_layer.weight: requires_grad=True
# GO:0006954_direct_gene_layer.bias: requires_grad=True
# GO:0045321_direct_gene_layer.weight: requires_grad=True
# GO:0045321_direct_gene_layer.bias: requires_grad=True
# GO:0002366_direct_gene_layer.weight: requires_grad=True
# GO:0002366_direct_gene_layer.bias: requires_grad=True
# GO:0097028_direct_gene_layer.weight: requires_grad=True
# GO:0097028_direct_gene_layer.bias: requires_grad=True
# GO:0045576_direct_gene_layer.weight: requires_grad=True
# GO:0045576_direct_gene_layer.bias: requires_grad=True
# GO:0042119_direct_gene_layer.weight: requires_grad=True
# GO:0042119_direct_gene_layer.bias: requires_grad=True
# GO:0002287_direct_gene_layer.weight: requires_grad=True
# GO:0002287_direct_gene_layer.bias: requires_grad=True
# GO:0002292_direct_gene_layer.weight: requires_grad=True
# GO:0002292_direct_gene_layer.bias: requires_grad=True
# GO:0030217_direct_gene_layer.weight: requires_grad=True
# GO:0030217_direct_gene_layer.bias: requires_grad=True
# GO:0043367_direct_gene_layer.weight: requires_grad=True
# GO:0043367_direct_gene_layer.bias: requires_grad=True
# GO:0042093_direct_gene_layer.weight: requires_grad=True
# GO:0042093_direct_gene_layer.bias: requires_grad=True
# GO:0002312_direct_gene_layer.weight: requires_grad=True
# GO:0002312_direct_gene_layer.bias: requires_grad=True
# GO:0042100_direct_gene_layer.weight: requires_grad=True
# GO:0042100_direct_gene_layer.bias: requires_grad=True
# GO:0030183_direct_gene_layer.weight: requires_grad=True
# GO:0030183_direct_gene_layer.bias: requires_grad=True
# GO:0010467_direct_gene_layer.weight: requires_grad=True
# GO:0010467_direct_gene_layer.bias: requires_grad=True
# GO:0010468_direct_gene_layer.weight: requires_grad=True
# GO:0010468_direct_gene_layer.bias: requires_grad=True
# GO:0009607_direct_gene_layer.weight: requires_grad=True
# GO:0009607_direct_gene_layer.bias: requires_grad=True
# GO:0002532_direct_gene_layer.weight: requires_grad=True
# GO:0002532_direct_gene_layer.bias: requires_grad=True
# GO:0002367_direct_gene_layer.weight: requires_grad=True
# GO:0002367_direct_gene_layer.bias: requires_grad=True
# GO:0002443_direct_gene_layer.weight: requires_grad=True
# GO:0002443_direct_gene_layer.bias: requires_grad=True
# GO:0050663_direct_gene_layer.weight: requires_grad=True
# GO:0050663_direct_gene_layer.bias: requires_grad=True
# GO:0015914_direct_gene_layer.weight: requires_grad=True
# GO:0015914_direct_gene_layer.bias: requires_grad=True
# GO:0002407_direct_gene_layer.weight: requires_grad=True
# GO:0002407_direct_gene_layer.bias: requires_grad=True
# GO:0002437_direct_gene_layer.weight: requires_grad=True
# GO:0002437_direct_gene_layer.bias: requires_grad=True
# GO:0046879_direct_gene_layer.weight: requires_grad=True
# GO:0046879_direct_gene_layer.bias: requires_grad=True
# GO:0002474_direct_gene_layer.weight: requires_grad=True
# GO:0002474_direct_gene_layer.bias: requires_grad=True
# GO:0019884_direct_gene_layer.weight: requires_grad=True
# GO:0019884_direct_gene_layer.bias: requires_grad=True
# GO:0002479_direct_gene_layer.weight: requires_grad=True
# GO:0002479_direct_gene_layer.bias: requires_grad=True
# GO:0006869_direct_gene_layer.weight: requires_grad=True
# GO:0006869_direct_gene_layer.bias: requires_grad=True
# GO:0002504_direct_gene_layer.weight: requires_grad=True
# GO:0002504_direct_gene_layer.bias: requires_grad=True
# GO:0050900_direct_gene_layer.weight: requires_grad=True
# GO:0050900_direct_gene_layer.bias: requires_grad=True
# GO:0043114_direct_gene_layer.weight: requires_grad=True
# GO:0043114_direct_gene_layer.bias: requires_grad=True
# GO:0016485_direct_gene_layer.weight: requires_grad=True
# GO:0016485_direct_gene_layer.bias: requires_grad=True
# GO:0030194_direct_gene_layer.weight: requires_grad=True
# GO:0030194_direct_gene_layer.bias: requires_grad=True
# GO:0002548_direct_gene_layer.weight: requires_grad=True
# GO:0002548_direct_gene_layer.bias: requires_grad=True
# GO:0043303_direct_gene_layer.weight: requires_grad=True
# GO:0043303_direct_gene_layer.bias: requires_grad=True
# GO:0046907_direct_gene_layer.weight: requires_grad=True
# GO:0046907_direct_gene_layer.bias: requires_grad=True
# GO:0002576_direct_gene_layer.weight: requires_grad=True
# GO:0002576_direct_gene_layer.bias: requires_grad=True
# GO:0002562_direct_gene_layer.weight: requires_grad=True
# GO:0002562_direct_gene_layer.bias: requires_grad=True
# GO:0002573_direct_gene_layer.weight: requires_grad=True
# GO:0002573_direct_gene_layer.bias: requires_grad=True
# GO:0030099_direct_gene_layer.weight: requires_grad=True
# GO:0030099_direct_gene_layer.bias: requires_grad=True
# GO:0045055_direct_gene_layer.weight: requires_grad=True
# GO:0045055_direct_gene_layer.bias: requires_grad=True
# GO:0002683_direct_gene_layer.weight: requires_grad=True
# GO:0002683_direct_gene_layer.bias: requires_grad=True
# GO:0002697_direct_gene_layer.weight: requires_grad=True
# GO:0002697_direct_gene_layer.bias: requires_grad=True
# GO:0002699_direct_gene_layer.weight: requires_grad=True
# GO:0002699_direct_gene_layer.bias: requires_grad=True
# GO:0002823_direct_gene_layer.weight: requires_grad=True
# GO:0002823_direct_gene_layer.bias: requires_grad=True
# GO:0051093_direct_gene_layer.weight: requires_grad=True
# GO:0051093_direct_gene_layer.bias: requires_grad=True
# GO:0051094_direct_gene_layer.weight: requires_grad=True
# GO:0051094_direct_gene_layer.bias: requires_grad=True
# GO:0010557_direct_gene_layer.weight: requires_grad=True
# GO:0010557_direct_gene_layer.bias: requires_grad=True
# GO:0050727_direct_gene_layer.weight: requires_grad=True
# GO:0050727_direct_gene_layer.bias: requires_grad=True
# GO:0050728_direct_gene_layer.weight: requires_grad=True
# GO:0050728_direct_gene_layer.bias: requires_grad=True
# GO:0050729_direct_gene_layer.weight: requires_grad=True
# GO:0050729_direct_gene_layer.bias: requires_grad=True
# GO:0030334_direct_gene_layer.weight: requires_grad=True
# GO:0030334_direct_gene_layer.bias: requires_grad=True
# GO:0002686_direct_gene_layer.weight: requires_grad=True
# GO:0002686_direct_gene_layer.bias: requires_grad=True
# GO:0030336_direct_gene_layer.weight: requires_grad=True
# GO:0030336_direct_gene_layer.bias: requires_grad=True
# GO:0030335_direct_gene_layer.weight: requires_grad=True
# GO:0030335_direct_gene_layer.bias: requires_grad=True
# GO:0050922_direct_gene_layer.weight: requires_grad=True
# GO:0050922_direct_gene_layer.bias: requires_grad=True
# GO:0002690_direct_gene_layer.weight: requires_grad=True
# GO:0002690_direct_gene_layer.bias: requires_grad=True
# GO:0002691_direct_gene_layer.weight: requires_grad=True
# GO:0002691_direct_gene_layer.bias: requires_grad=True
# GO:0002695_direct_gene_layer.weight: requires_grad=True
# GO:0002695_direct_gene_layer.bias: requires_grad=True
# GO:0050866_direct_gene_layer.weight: requires_grad=True
# GO:0050866_direct_gene_layer.bias: requires_grad=True
# GO:0050867_direct_gene_layer.weight: requires_grad=True
# GO:0050867_direct_gene_layer.bias: requires_grad=True
# GO:0002704_direct_gene_layer.weight: requires_grad=True
# GO:0002704_direct_gene_layer.bias: requires_grad=True
# GO:0002719_direct_gene_layer.weight: requires_grad=True
# GO:0002719_direct_gene_layer.bias: requires_grad=True
# ...
# discriminator1GO:0001817.weight: requires_grad=True
# discriminator1GO:0001817.bias: requires_grad=True
# discriminator2GO:0001817.weight: requires_grad=True
# discriminator2GO:0001817.bias: requires_grad=True
# GO:0051241_linear_layer.weight: requires_grad=True
# GO:0051241_linear_layer.bias: requires_grad=True
# GO:0051241_batchnorm_layer.weight: requires_grad=True
# GO:0051241_batchnorm_layer.bias: requires_grad=True
# GO:0051241_aux_linear_layer1.weight: requires_grad=True
# GO:0051241_aux_linear_layer1.bias: requires_grad=True
# GO:0051241_aux_linear_layer2.weight: requires_grad=True
# GO:0051241_aux_linear_layer2.bias: requires_grad=True
# GO:0051241_aux_linear_layer3.weight: requires_grad=True
# GO:0051241_aux_linear_layer3.bias: requires_grad=True
# GO:0051241_aux_linear_layer4.weight: requires_grad=True
# GO:0051241_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0051241.weight: requires_grad=True
# discriminator1GO:0051241.bias: requires_grad=True
# discriminator2GO:0051241.weight: requires_grad=True
# discriminator2GO:0051241.bias: requires_grad=True
# GO:0051240_linear_layer.weight: requires_grad=True
# GO:0051240_linear_layer.bias: requires_grad=True
# GO:0051240_batchnorm_layer.weight: requires_grad=True
# GO:0051240_batchnorm_layer.bias: requires_grad=True
# GO:0051240_aux_linear_layer1.weight: requires_grad=True
# GO:0051240_aux_linear_layer1.bias: requires_grad=True
# GO:0051240_aux_linear_layer2.weight: requires_grad=True
# GO:0051240_aux_linear_layer2.bias: requires_grad=True
# GO:0051240_aux_linear_layer3.weight: requires_grad=True
# GO:0051240_aux_linear_layer3.bias: requires_grad=True
# GO:0051240_aux_linear_layer4.weight: requires_grad=True
# GO:0051240_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0051240.weight: requires_grad=True
# discriminator1GO:0051240.bias: requires_grad=True
# discriminator2GO:0051240.weight: requires_grad=True
# discriminator2GO:0051240.bias: requires_grad=True
# GO:0048513_linear_layer.weight: requires_grad=True
# GO:0048513_linear_layer.bias: requires_grad=True
# GO:0048513_batchnorm_layer.weight: requires_grad=True
# GO:0048513_batchnorm_layer.bias: requires_grad=True
# GO:0048513_aux_linear_layer1.weight: requires_grad=True
# GO:0048513_aux_linear_layer1.bias: requires_grad=True
# GO:0048513_aux_linear_layer2.weight: requires_grad=True
# GO:0048513_aux_linear_layer2.bias: requires_grad=True
# GO:0048513_aux_linear_layer3.weight: requires_grad=True
# GO:0048513_aux_linear_layer3.bias: requires_grad=True
# GO:0048513_aux_linear_layer4.weight: requires_grad=True
# GO:0048513_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0048513.weight: requires_grad=True
# discriminator1GO:0048513.bias: requires_grad=True
# discriminator2GO:0048513.weight: requires_grad=True
# discriminator2GO:0048513.bias: requires_grad=True
# GO:0007507_linear_layer.weight: requires_grad=True
# GO:0007507_linear_layer.bias: requires_grad=True
# GO:0007507_batchnorm_layer.weight: requires_grad=True
# GO:0007507_batchnorm_layer.bias: requires_grad=True
# GO:0007507_aux_linear_layer1.weight: requires_grad=True
# GO:0007507_aux_linear_layer1.bias: requires_grad=True
# GO:0007507_aux_linear_layer2.weight: requires_grad=True
# GO:0007507_aux_linear_layer2.bias: requires_grad=True
# GO:0007507_aux_linear_layer3.weight: requires_grad=True
# GO:0007507_aux_linear_layer3.bias: requires_grad=True
# GO:0007507_aux_linear_layer4.weight: requires_grad=True
# GO:0007507_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0007507.weight: requires_grad=True
# discriminator1GO:0007507.bias: requires_grad=True
# discriminator2GO:0007507.weight: requires_grad=True
# discriminator2GO:0007507.bias: requires_grad=True
# GO:0009968_linear_layer.weight: requires_grad=True
# GO:0009968_linear_layer.bias: requires_grad=True
# GO:0009968_batchnorm_layer.weight: requires_grad=True
# GO:0009968_batchnorm_layer.bias: requires_grad=True
# GO:0009968_aux_linear_layer1.weight: requires_grad=True
# GO:0009968_aux_linear_layer1.bias: requires_grad=True
# GO:0009968_aux_linear_layer2.weight: requires_grad=True
# GO:0009968_aux_linear_layer2.bias: requires_grad=True
# GO:0009968_aux_linear_layer3.weight: requires_grad=True
# GO:0009968_aux_linear_layer3.bias: requires_grad=True
# GO:0009968_aux_linear_layer4.weight: requires_grad=True
# GO:0009968_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0009968.weight: requires_grad=True
# discriminator1GO:0009968.bias: requires_grad=True
# discriminator2GO:0009968.weight: requires_grad=True
# discriminator2GO:0009968.bias: requires_grad=True
# GO:0002697_linear_layer.weight: requires_grad=True
# GO:0002697_linear_layer.bias: requires_grad=True
# GO:0002697_batchnorm_layer.weight: requires_grad=True
# GO:0002697_batchnorm_layer.bias: requires_grad=True
# GO:0002697_aux_linear_layer1.weight: requires_grad=True
# GO:0002697_aux_linear_layer1.bias: requires_grad=True
# GO:0002697_aux_linear_layer2.weight: requires_grad=True
# GO:0002697_aux_linear_layer2.bias: requires_grad=True
# GO:0002697_aux_linear_layer3.weight: requires_grad=True
# GO:0002697_aux_linear_layer3.bias: requires_grad=True
# GO:0002697_aux_linear_layer4.weight: requires_grad=True
# GO:0002697_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0002697.weight: requires_grad=True
# discriminator1GO:0002697.bias: requires_grad=True
# discriminator2GO:0002697.weight: requires_grad=True
# discriminator2GO:0002697.bias: requires_grad=True
# GO:0051094_linear_layer.weight: requires_grad=True
# GO:0051094_linear_layer.bias: requires_grad=True
# GO:0051094_batchnorm_layer.weight: requires_grad=True
# GO:0051094_batchnorm_layer.bias: requires_grad=True
# GO:0051094_aux_linear_layer1.weight: requires_grad=True
# GO:0051094_aux_linear_layer1.bias: requires_grad=True
# GO:0051094_aux_linear_layer2.weight: requires_grad=True
# GO:0051094_aux_linear_layer2.bias: requires_grad=True
# GO:0051094_aux_linear_layer3.weight: requires_grad=True
# GO:0051094_aux_linear_layer3.bias: requires_grad=True
# GO:0051094_aux_linear_layer4.weight: requires_grad=True
# GO:0051094_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0051094.weight: requires_grad=True
# discriminator1GO:0051094.bias: requires_grad=True
# discriminator2GO:0051094.weight: requires_grad=True
# discriminator2GO:0051094.bias: requires_grad=True
# GO:0009888_linear_layer.weight: requires_grad=True
# GO:0009888_linear_layer.bias: requires_grad=True
# GO:0009888_batchnorm_layer.weight: requires_grad=True
# GO:0009888_batchnorm_layer.bias: requires_grad=True
# GO:0009888_aux_linear_layer1.weight: requires_grad=True
# GO:0009888_aux_linear_layer1.bias: requires_grad=True
# GO:0009888_aux_linear_layer2.weight: requires_grad=True
# GO:0009888_aux_linear_layer2.bias: requires_grad=True
# GO:0009888_aux_linear_layer3.weight: requires_grad=True
# GO:0009888_aux_linear_layer3.bias: requires_grad=True
# GO:0009888_aux_linear_layer4.weight: requires_grad=True
# GO:0009888_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0009888.weight: requires_grad=True
# discriminator1GO:0009888.bias: requires_grad=True
# discriminator2GO:0009888.weight: requires_grad=True
# discriminator2GO:0009888.bias: requires_grad=True
# GO:0003008_linear_layer.weight: requires_grad=True
# GO:0003008_linear_layer.bias: requires_grad=True
# GO:0003008_batchnorm_layer.weight: requires_grad=True
# GO:0003008_batchnorm_layer.bias: requires_grad=True
# GO:0003008_aux_linear_layer1.weight: requires_grad=True
# GO:0003008_aux_linear_layer1.bias: requires_grad=True
# GO:0003008_aux_linear_layer2.weight: requires_grad=True
# GO:0003008_aux_linear_layer2.bias: requires_grad=True
# GO:0003008_aux_linear_layer3.weight: requires_grad=True
# GO:0003008_aux_linear_layer3.bias: requires_grad=True
# GO:0003008_aux_linear_layer4.weight: requires_grad=True
# GO:0003008_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0003008.weight: requires_grad=True
# discriminator1GO:0003008.bias: requires_grad=True
# discriminator2GO:0003008.weight: requires_grad=True
# discriminator2GO:0003008.bias: requires_grad=True
# GO:0042127_linear_layer.weight: requires_grad=True
# GO:0042127_linear_layer.bias: requires_grad=True
# GO:0042127_batchnorm_layer.weight: requires_grad=True
# GO:0042127_batchnorm_layer.bias: requires_grad=True
# GO:0042127_aux_linear_layer1.weight: requires_grad=True
# GO:0042127_aux_linear_layer1.bias: requires_grad=True
# GO:0042127_aux_linear_layer2.weight: requires_grad=True
# GO:0042127_aux_linear_layer2.bias: requires_grad=True
# GO:0042127_aux_linear_layer3.weight: requires_grad=True
# GO:0042127_aux_linear_layer3.bias: requires_grad=True
# GO:0042127_aux_linear_layer4.weight: requires_grad=True
# GO:0042127_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0042127.weight: requires_grad=True
# discriminator1GO:0042127.bias: requires_grad=True
# discriminator2GO:0042127.weight: requires_grad=True
# discriminator2GO:0042127.bias: requires_grad=True
# GO:0019637_linear_layer.weight: requires_grad=True
# GO:0019637_linear_layer.bias: requires_grad=True
# GO:0019637_batchnorm_layer.weight: requires_grad=True
# GO:0019637_batchnorm_layer.bias: requires_grad=True
# GO:0019637_aux_linear_layer1.weight: requires_grad=True
# GO:0019637_aux_linear_layer1.bias: requires_grad=True
# GO:0019637_aux_linear_layer2.weight: requires_grad=True
# GO:0019637_aux_linear_layer2.bias: requires_grad=True
# GO:0019637_aux_linear_layer3.weight: requires_grad=True
# GO:0019637_aux_linear_layer3.bias: requires_grad=True
# GO:0019637_aux_linear_layer4.weight: requires_grad=True
# GO:0019637_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0019637.weight: requires_grad=True
# discriminator1GO:0019637.bias: requires_grad=True
# discriminator2GO:0019637.weight: requires_grad=True
# discriminator2GO:0019637.bias: requires_grad=True
# GO:0044249_linear_layer.weight: requires_grad=True
# GO:0044249_linear_layer.bias: requires_grad=True
# GO:0044249_batchnorm_layer.weight: requires_grad=True
# GO:0044249_batchnorm_layer.bias: requires_grad=True
# GO:0044249_aux_linear_layer1.weight: requires_grad=True
# GO:0044249_aux_linear_layer1.bias: requires_grad=True
# GO:0044249_aux_linear_layer2.weight: requires_grad=True
# GO:0044249_aux_linear_layer2.bias: requires_grad=True
# GO:0044249_aux_linear_layer3.weight: requires_grad=True
# GO:0044249_aux_linear_layer3.bias: requires_grad=True
# GO:0044249_aux_linear_layer4.weight: requires_grad=True
# GO:0044249_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0044249.weight: requires_grad=True
# discriminator1GO:0044249.bias: requires_grad=True
# discriminator2GO:0044249.weight: requires_grad=True
# discriminator2GO:0044249.bias: requires_grad=True
# GO:0006996_linear_layer.weight: requires_grad=True
# GO:0006996_linear_layer.bias: requires_grad=True
# GO:0006996_batchnorm_layer.weight: requires_grad=True
# GO:0006996_batchnorm_layer.bias: requires_grad=True
# GO:0006996_aux_linear_layer1.weight: requires_grad=True
# GO:0006996_aux_linear_layer1.bias: requires_grad=True
# GO:0006996_aux_linear_layer2.weight: requires_grad=True
# GO:0006996_aux_linear_layer2.bias: requires_grad=True
# GO:0006996_aux_linear_layer3.weight: requires_grad=True
# GO:0006996_aux_linear_layer3.bias: requires_grad=True
# GO:0006996_aux_linear_layer4.weight: requires_grad=True
# GO:0006996_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0006996.weight: requires_grad=True
# discriminator1GO:0006996.bias: requires_grad=True
# discriminator2GO:0006996.weight: requires_grad=True
# discriminator2GO:0006996.bias: requires_grad=True
# GO:0010564_linear_layer.weight: requires_grad=True
# GO:0010564_linear_layer.bias: requires_grad=True
# GO:0010564_batchnorm_layer.weight: requires_grad=True
# GO:0010564_batchnorm_layer.bias: requires_grad=True
# GO:0010564_aux_linear_layer1.weight: requires_grad=True
# GO:0010564_aux_linear_layer1.bias: requires_grad=True
# GO:0010564_aux_linear_layer2.weight: requires_grad=True
# GO:0010564_aux_linear_layer2.bias: requires_grad=True
# GO:0010564_aux_linear_layer3.weight: requires_grad=True
# GO:0010564_aux_linear_layer3.bias: requires_grad=True
# GO:0010564_aux_linear_layer4.weight: requires_grad=True
# GO:0010564_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0010564.weight: requires_grad=True
# discriminator1GO:0010564.bias: requires_grad=True
# discriminator2GO:0010564.weight: requires_grad=True
# discriminator2GO:0010564.bias: requires_grad=True
# GO:0080135_linear_layer.weight: requires_grad=True
# GO:0080135_linear_layer.bias: requires_grad=True
# GO:0080135_batchnorm_layer.weight: requires_grad=True
# GO:0080135_batchnorm_layer.bias: requires_grad=True
# GO:0080135_aux_linear_layer1.weight: requires_grad=True
# GO:0080135_aux_linear_layer1.bias: requires_grad=True
# GO:0080135_aux_linear_layer2.weight: requires_grad=True
# GO:0080135_aux_linear_layer2.bias: requires_grad=True
# GO:0080135_aux_linear_layer3.weight: requires_grad=True
# GO:0080135_aux_linear_layer3.bias: requires_grad=True
# GO:0080135_aux_linear_layer4.weight: requires_grad=True
# GO:0080135_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0080135.weight: requires_grad=True
# discriminator1GO:0080135.bias: requires_grad=True
# discriminator2GO:0080135.weight: requires_grad=True
# discriminator2GO:0080135.bias: requires_grad=True
# GO:0042981_linear_layer.weight: requires_grad=True
# GO:0042981_linear_layer.bias: requires_grad=True
# GO:0042981_batchnorm_layer.weight: requires_grad=True
# GO:0042981_batchnorm_layer.bias: requires_grad=True
# GO:0042981_aux_linear_layer1.weight: requires_grad=True
# GO:0042981_aux_linear_layer1.bias: requires_grad=True
# GO:0042981_aux_linear_layer2.weight: requires_grad=True
# GO:0042981_aux_linear_layer2.bias: requires_grad=True
# GO:0042981_aux_linear_layer3.weight: requires_grad=True
# GO:0042981_aux_linear_layer3.bias: requires_grad=True
# GO:0042981_aux_linear_layer4.weight: requires_grad=True
# GO:0042981_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0042981.weight: requires_grad=True
# discriminator1GO:0042981.bias: requires_grad=True
# discriminator2GO:0042981.weight: requires_grad=True
# discriminator2GO:0042981.bias: requires_grad=True
# GO:1901701_linear_layer.weight: requires_grad=True
# GO:1901701_linear_layer.bias: requires_grad=True
# GO:1901701_batchnorm_layer.weight: requires_grad=True
# GO:1901701_batchnorm_layer.bias: requires_grad=True
# GO:1901701_aux_linear_layer1.weight: requires_grad=True
# GO:1901701_aux_linear_layer1.bias: requires_grad=True
# GO:1901701_aux_linear_layer2.weight: requires_grad=True
# GO:1901701_aux_linear_layer2.bias: requires_grad=True
# GO:1901701_aux_linear_layer3.weight: requires_grad=True
# GO:1901701_aux_linear_layer3.bias: requires_grad=True
# GO:1901701_aux_linear_layer4.weight: requires_grad=True
# GO:1901701_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:1901701.weight: requires_grad=True
# discriminator1GO:1901701.bias: requires_grad=True
# discriminator2GO:1901701.weight: requires_grad=True
# discriminator2GO:1901701.bias: requires_grad=True
# GO:0008150_linear_layer.weight: requires_grad=True
# GO:0008150_linear_layer.bias: requires_grad=True
# GO:0008150_batchnorm_layer.weight: requires_grad=True
# GO:0008150_batchnorm_layer.bias: requires_grad=True
# GO:0008150_aux_linear_layer1.weight: requires_grad=True
# GO:0008150_aux_linear_layer1.bias: requires_grad=True
# GO:0008150_aux_linear_layer2.weight: requires_grad=True
# GO:0008150_aux_linear_layer2.bias: requires_grad=True
# GO:0008150_aux_linear_layer3.weight: requires_grad=True
# GO:0008150_aux_linear_layer3.bias: requires_grad=True
# GO:0008150_aux_linear_layer4.weight: requires_grad=True
# GO:0008150_aux_linear_layer4.bias: requires_grad=True
# discriminator1GO:0008150.weight: requires_grad=True
# discriminator1GO:0008150.bias: requires_grad=True
# discriminator2GO:0008150.weight: requires_grad=True
# discriminator2GO:0008150.bias: requires_grad=True
# final_linear_layer.weight: requires_grad=True
# final_linear_layer.bias: requires_grad=True
# final_batchnorm_layer.weight: requires_grad=True
# final_batchnorm_layer.bias: requires_grad=True
# final_aux_linear_layer.weight: requires_grad=True
# final_aux_linear_layer.bias: requires_grad=True
# final_linear_layer_output.weight: requires_grad=True
# final_linear_layer_output.bias: requires_grad=True
# decoder_affine.weight: requires_grad=True
# decoder_affine.bias: requires_grad=True

# %%
model.to(DEVICE)
learning_rate = 0.002
torch.manual_seed(0)
loss_list = []
accu_list = []
train_epochs = 500

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.99), eps=1e-05, weight_decay = 1e-4)


term_mask_map = create_term_mask(model.term_direct_gene_map, gene_dim=num_genes, device=DEVICE)

optimizer.zero_grad()

best_epoch = 0
best_accu = 0
best_model_path = "model_classification_no_teacher_test.pt"

for name, param in model.named_parameters():
    term_name = name.split('_')[0]

    if '_direct_gene_layer.weight' in name:
        param.data = torch.mul(param.data, term_mask_map[term_name].to(DEVICE)) * 1
    else:
        param.data = param.data * 1

tepoch = tqdm.tqdm(range(train_epochs))
for epoch in tepoch:

    # Train
    model.train()
    train_predict = torch.zeros(0, 0).to(DEVICE)

    for i, (data, labels) in enumerate(train_loader):
        # Get the information from teacher model
        # Convert torch tensor to Variable

        # Forward + Backward + Optimize
        optimizer.zero_grad()  # zero the gradient buffer

        # Here term_NN_out_map is a dictionary
        logits, mu, log_var, aux_out_map, aux_cancer_map, term_NN_out_map, term_original_children = model(data.to(DEVICE))
        
        student_feats = term_NN_out_map

        if train_predict.size()[0] == 0:
            train_predict = aux_out_map["final"].data
        else:
            train_predict = torch.cat([train_predict, aux_out_map["final"].data], dim=0)

        loss_vae, class_loss, KLD = model.loss_log_vae(
            logits=logits, y=labels.to(DEVICE), mu=mu, log_var=log_var, beta=0.001
        )

        loss_intermidiate = model.intermediate_loss_cancer(aux_cancer_map, labels.to(DEVICE))


        total_loss = torch.mean(loss_vae + 0.2 * loss_intermidiate)
        
        
        tmp_loss = total_loss.item()
        total_loss.backward()

        for name, param in model.named_parameters():
            if "_direct_gene_layer.weight" not in name:
                continue
            term_name = name.split("_")[0]
            # print name, param.grad.data.size(), term_mask_map[term_name].size()
            if param.requires_grad and param.grad is not None:
                term_name = name.split("_")[0]
                param.grad.data = torch.mul(param.grad.data, term_mask_map[term_name])

        optimizer.step()
    
    model.eval()
    with torch.no_grad():
        (inputdata, labels) = next(iter(test_loader))
        inputdata = inputdata.to(DEVICE, non_blocking=True)
        labels = labels.to(DEVICE, non_blocking=True)

        logits, mu, log_var, aux_out_map, aux_cancer_map, term_NN_out_map, term_original_children = model(inputdata)
        preds = torch.argmax(logits, dim=1)
        accu = (preds == labels).float().mean().item()
    
        loss_list.append(tmp_loss)
        accu_list.append(accu)
    # if epoch % 10 == 0:
    if accu > best_accu:
        best_epoch = epoch
        best_accu = accu
        # torch.save(model, best_model_path)
           
    tepoch.set_postfix({"Epoch": epoch, "Loss": tmp_loss, "Accuracy": accu})
        
print(f"Epoch {best_epoch}: New best model saved with accuracy {best_accu:.4f}")
print("Training complete. Best model saved at:", best_model_path)
# Out:
#   0%|          | 2/500 [00:10<44:00,  5.30s/it, Epoch=1, Loss=2.11e+3, Accuracy=0.0332]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/yyu27/D-PACKAGE/tcga_classification_benchmark.ipynb Cell 10 line 8
#      <a href='vscode-notebook-cell://ondemand.orc.gmu.edu/home/yyu27/D-PACKAGE/tcga_classification_benchmark.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=77'>78</a> inputdata = inputdata.to(DEVICE, non_blocking=True)
#      <a href='vscode-notebook-cell://ondemand.orc.gmu.edu/home/yyu27/D-PACKAGE/tcga_classification_benchmark.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=78'>79</a> labels = labels.to(DEVICE, non_blocking=True)
# ---> <a href='vscode-notebook-cell://ondemand.orc.gmu.edu/home/yyu27/D-PACKAGE/tcga_classification_benchmark.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=80'>81</a> logits, mu, log_var, aux_out_map, aux_cancer_map, term_NN_out_map, term_original_children = model(inputdata)
#      <a href='vscode-notebook-cell://ondemand.orc.gmu.edu/home/yyu27/D-PACKAGE/tcga_classification_benchmark.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=81'>82</a> preds = torch.argmax(logits, dim=1)
#      <a href='vscode-notebook-cell://ondemand.orc.gmu.edu/home/yyu27/D-PACKAGE/tcga_classification_benchmark.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=82'>83</a> accu = (preds == labels).float().mean().item()
#
# KeyboardInterrupt:

# %%
with open('tcga_loss_list_no_teacher.txt', 'w') as f:
    for loss in loss_list:
        f.write(f"{loss}\n")
    

with open('tcga_accuracy_list_no_teacher.txt', 'w') as f:
    for loss in accu_list:
        f.write(f"{loss}\n")

# %%
plt.plot(accu_list)
